# %% [markdown]
# <a href="https://colab.research.google.com/github/Zencriel/Bias_In_MachineLearning_Research/blob/main/Credit_Scoring_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importing libraries & functions

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Importing dataset

# %%
dataset=pd.read_excel("/content/a_Dataset_CreditScoring.xlsx")

# %% [markdown]
# ### Data preparation

# %%
# shows count of rows and columns
dataset.shape
# Out:
# (3000, 30)

# %%
#shows first few rows of the code
dataset.head()
# Out:
#    TARGET    ID  DerogCnt  CollectCnt  BanruptcyInd  InqCnt06  InqTimeLast  \
# 0       1   582         3           3             0         4          0.0
# 1       1   662        15           9             0         3          1.0
# 2       1   805         0           0             0         1          5.0
# 3       1  1175         8           5             0         6          1.0
# 4       1  1373         3           1             0         9          0.0
#
#    InqFinanceCnt24  TLTimeFirst  TLTimeLast  ...  TL50UtilCnt  TLBalHCPct  \
# 0                5          117          27  ...          3.0      0.9179
# 1                3           14          14  ...          1.0      0.8000
# 2                1          354           7  ...          5.0      0.3552
# 3               10           16           4  ...          3.0      0.9127
# 4                8          130          52  ...          1.0      1.2511
#
# ...

# %%
#dropping customer ID column from the dataset
dataset=dataset.drop('ID',axis=1)
dataset.shape
# Out:
# (3000, 29)

# %%
# explore missing values
dataset.isna().sum()
# Out:
# TARGET               0
# DerogCnt             0
# CollectCnt           0
# BanruptcyInd         0
# InqCnt06             0
# InqTimeLast        188
# InqFinanceCnt24      0
# TLTimeFirst          0
# TLTimeLast           0
# TLCnt03              0
# TLCnt12              0
# TLCnt24              0
# TLCnt                3
# TLSum               40
# TLMaxSum            40
# TLSatCnt             4
# TLDel60Cnt           0
# TLBadCnt24           0
# TL75UtilCnt         99
# TL50UtilCnt         99
# TLBalHCPct          41
# TLSatPct             4
# TLDel3060Cnt24       0
# TLDel90Cnt24         0
# TLDel60CntAll        0
# TLOpenPct            3
# TLBadDerogCnt        0
# TLDel60Cnt24         0
# TLOpen24Pct          3
# dtype: int64

# %%
# filling missing values with mean
dataset=dataset.fillna(dataset.mean())

# %%
# explore missing values post missing value fix
dataset.isna().sum()
# Out:
# TARGET             0
# DerogCnt           0
# CollectCnt         0
# BanruptcyInd       0
# InqCnt06           0
# InqTimeLast        0
# InqFinanceCnt24    0
# TLTimeFirst        0
# TLTimeLast         0
# TLCnt03            0
# TLCnt12            0
# TLCnt24            0
# TLCnt              0
# TLSum              0
# TLMaxSum           0
# TLSatCnt           0
# TLDel60Cnt         0
# TLBadCnt24         0
# TL75UtilCnt        0
# TL50UtilCnt        0
# TLBalHCPct         0
# TLSatPct           0
# TLDel3060Cnt24     0
# TLDel90Cnt24       0
# TLDel60CntAll      0
# TLOpenPct          0
# TLBadDerogCnt      0
# TLDel60Cnt24       0
# TLOpen24Pct        0
# dtype: int64

# %% [markdown]
# ### Train Test Split

# %%
y = dataset.iloc[:, 0].values
X = dataset.iloc[:, 1:29].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=0,
                                                    stratify=y)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Exporting Normalisation Coefficients for later use in prediction
import joblib
joblib.dump(sc, '/content/Test')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-22-4036c7c4db70> in <cell line: 3>()
#       1 # Exporting Normalisation Coefficients for later use in prediction
#       2 import joblib
# ----> 3 joblib.dump(sc, '/content/Test')
#
# /usr/local/lib/python3.10/dist-packages/joblib/numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     550             NumpyPickler(f, protocol=protocol).dump(value)
#     551     elif is_filename:
# --> 552         with open(filename, 'wb') as f:
#     553             NumpyPickler(f, protocol=protocol).dump(value)
#     554     else:
#
# IsADirectoryError: [Errno 21] Is a directory: '/content/Test'

# %% [markdown]
# ### Risk Model building

# %%
classifier =  LogisticRegression()
classifier.fit(X_train, y_train)
y_pred = classifier.predict(X_test)

# %%
# Exporting Logistic Regression Classifier for later use in prediction

import joblib
joblib.dump(classifier, '/content/')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-92d3383fee74> in <cell line: 4>()
#       2
#       3 import joblib
# ----> 4 joblib.dump(classifier, '/content/')
#
# NameError: name 'classifier' is not defined

# %% [markdown]
# ### Model *performance*

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[487  13]
#  [ 87  13]]

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8333333333333334

# %% [markdown]
# ### Writing output file

# %%
predictions = classifier.predict_proba(X_test)
predictions
# Out:
# array([[0.61644691, 0.38355309],
#        [0.9885656 , 0.0114344 ],
#        [0.87069686, 0.12930314],
#        ...,
#        [0.94450568, 0.05549432],
#        [0.46756903, 0.53243097],
#        [0.94014209, 0.05985791]])

# %%
# writing model output file

df_prediction_prob = pd.DataFrame(predictions, columns = ['prob_0', 'prob_1'])
df_prediction_target = pd.DataFrame(classifier.predict(X_test), columns = ['predicted_TARGET'])
df_test_dataset = pd.DataFrame(y_test,columns= ['Actual Outcome'])

dfx=pd.concat([df_test_dataset, df_prediction_prob, df_prediction_target], axis=1)

dfx.to_csv("/content/drive/My Drive/1_LiveProjects/Project1_Credit_Scoring/c1_Model_Prediction.xlsx", sep=',', encoding='UTF-8')

dfx.head()
# Out:
#    Actual Outcome    prob_0    prob_1  predicted_TARGET
# 0             1.0  0.616447  0.383553               0.0
# 1             0.0  0.988566  0.011434               0.0
# 2             1.0  0.870697  0.129303               0.0
# 3             0.0  0.953963  0.046037               0.0
# 4             1.0  0.726633  0.273367               0.0
